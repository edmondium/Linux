# %%
5
# Out:
# 5

# %%
3+2
# Out:
# 5

# %%
5/3
# Out:
# 1.6666666666666667

# %%
5*3
# Out:
# 15

# %%
var1 = 50

# %%
var1
# Out:
# 50

# %%
var1*5
# Out:
# 250

# %%
var2 = 'haha'

# %%
var2
# Out:
# 'haha'

# %%
var2*3
# Out:
# 'hahahahahaha'

# %%
type(var2)
# Out:
# str

# %%
type(var1)
# Out:
# int

# %%
var3 = [1, 2, 3, 4, 5, 6]

# %%
var3
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
var3[1]
# Out:
# 2

# %%
var3[0]
# Out:
# 1

# %%
var3*3
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %%
var3[-1]
# Out:
# 6

# %%
var4 = [3, 4, 'a', 'b']

# %%
var4.append('c')

# %%
var4
# Out:
# [3, 4, 'a', 'b', 'c']

# %%
var4.insert(2, 6)

# %%
var4
# Out:
# [3, 4, 6, 'a', 'b', 'c']

# %%
var4[3]
# Out:
# 'a'
